# %% [markdown]
# # Analisi Teleriscaldamento Torino
# **Data:** Giugno 2026
# **Fonte:** ARERA
# **Autore:** Marco Sicbaldi — Energy Research Lab

# %%
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path

# Percorsi
ROOT = Path().resolve().parent.parent.parent
RAW = ROOT / "data" / "raw" / "2026" / "arera"
OUTPUT = Path().resolve().parent / "outputs"

print("Percorsi configurati correttamente")
print(f"Dati: {RAW}")
print(f"Output: {OUTPUT}")
# Out:
# Percorsi configurati correttamente
# Dati: C:\Users\marco\Desktop\energy_research_lab\data\raw\2026\arera
# Output: C:\Users\marco\Desktop\energy_research_lab\projects\2026_06_Teleriscaldamento_Torino_EC\outputs

# %%
## 1. Caricamento dati

# %%
# df = pd.read_csv(RAW / "nome_file.csv")
# df.head()
print("Pronto per caricare i dati quando disponibili.")
# Out:
# Pronto per caricare i dati quando disponibili.
